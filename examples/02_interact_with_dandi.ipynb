# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")
    

from nwbwidgets import nwb2widget

from functional_connectivity.io import DandiHandler
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dh = DandiHandler("000041", "sub-BWRat17/sub-BWRat17_ses-BWRat17-121912_ecephys.nwb")

# %%
print(s3_url := dh.get_s3_url())
# Out:
# https://dandiarchive.s3.amazonaws.com/blobs/ad8/b1e/ad8b1e79-102a-4cc9-98a1-1ee60d1a3396

# %%
dh.download()
# Out:
# /Users/tzuchi/anaconda3/envs/fc/lib/python3.11/site-packages/hdmf/spec/namespace.py:531: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.1.3 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /Users/tzuchi/anaconda3/envs/fc/lib/python3.11/site-packages/hdmf/spec/namespace.py:531: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.6.0-alpha is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."

# %%
nwbfile = dh.read()

# %%
dir(nwbfile)
# Out:
# ['_AbstractContainer__children',
#  '_AbstractContainer__container_source',
#  '_AbstractContainer__field_values',
#  '_AbstractContainer__fieldsconf',
#  '_AbstractContainer__gather_fields',
#  '_AbstractContainer__modified',
#  '_AbstractContainer__name',
#  '_AbstractContainer__obj',
#  '_AbstractContainer__object_id',
#  '_AbstractContainer__parent',
#  '_AbstractContainer__read_io',
#  '_Container__smart_str',
#  '_Container__smart_str_dict',
#  '_Container__smart_str_list',
#  '_MultiContainerInterface__add_article',
#  '_MultiContainerInterface__build_class',
#  '_MultiContainerInterface__build_conf_methods',
#  '_MultiContainerInterface__join',
#  '_MultiContainerInterface__make_add',
#  '_MultiContainerInterface__make_constructor',
#  '_MultiContainerInterface__make_create',
#  '_MultiContainerInterface__make_get',
#  '_MultiContainerInterface__make_getitem',
#  '_MultiContainerInterface__make_getter',
#  '_MultiContainerInterface__make_setter',
# ...

# %%
nwbfile
# Out:
# root pynwb.file.NWBFile at 0x6701567056
# Fields:
#   devices: {
#     implant <class 'pynwb.device.Device'>
#   }
#   electrode_groups: {
#     shank1 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank2 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank3 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank4 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank5 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank6 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank7 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank8 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank9 <class 'pynwb.ecephys.ElectrodeGroup'>
#   }
#   electrodes: electrodes <class 'hdmf.common.table.DynamicTable'>
#   experimenter: ['Brendon Watson']
#   file_create_date: [datetime.datetime(2020, 10, 3, 13, 49, 41, 955624, tzinfo=tzoffset(None, -14400))]
#   identifier: BWRat17_121912
#   institution: NYU
#   lab: Buzsaki
#   processing: {
#     behavior <class 'pynwb.base.ProcessingModule'>,
# ...

# %%
nwbfile.units
# Out:
# units pynwb.misc.Units at 0x6701904336
# Fields:
#   colnames: ['global_id' 'shank_id' 'cell_type' 'region' 'electrode_group'
#  'spike_times']
#   columns: (
#     global_id <class 'hdmf.common.table.VectorData'>,
#     shank_id <class 'hdmf.common.table.VectorData'>,
#     cell_type <class 'hdmf.common.table.VectorData'>,
#     region <class 'hdmf.common.table.VectorData'>,
#     electrode_group <class 'hdmf.common.table.VectorData'>,
#     spike_times_index <class 'hdmf.common.table.VectorIndex'>,
#     spike_times <class 'hdmf.common.table.VectorData'>
#   )
#   description: Autogenerated by NWBFile
#   id: id <class 'hdmf.common.table.ElementIdentifiers'>
#   waveform_unit: volts

# %%
nwbfile.electrodes.to_dataframe()
# Out:
#      x   y   z  imp location filtering  \
# id
# 0  NaN NaN NaN -1.0  unknown      none
# 1  NaN NaN NaN -1.0  unknown      none
# 2  NaN NaN NaN -1.0  unknown      none
# 3  NaN NaN NaN -1.0  unknown      none
# 4  NaN NaN NaN -1.0  unknown      none
# ..  ..  ..  ..  ...      ...       ...
# 63 NaN NaN NaN -1.0  unknown      none
# 64 NaN NaN NaN -1.0  unknown      none
# 65 NaN NaN NaN -1.0  unknown      none
# 66 NaN NaN NaN -1.0  unknown      none
# 67 NaN NaN NaN -1.0  unknown      none
#
#                                                 group group_name  \
# id
# 0   shank1 pynwb.ecephys.ElectrodeGroup at 0x67018...     shank1
# 1   shank1 pynwb.ecephys.ElectrodeGroup at 0x67018...     shank1
# 2   shank1 pynwb.ecephys.ElectrodeGroup at 0x67018...     shank1
# 3   shank1 pynwb.ecephys.ElectrodeGroup at 0x67018...     shank1
# 4   shank1 pynwb.ecephys.ElectrodeGroup at 0x67018...     shank1
# ..                                                ...        ...
# ...

# %%
nwb2widget(nwbfile)

# %%
df = nwbfile.units.to_dataframe()

# %%
df
# Out:
#     global_id  shank_id   cell_type region  \
# id
# 0           1         0  excitatory    CTX
# 1           2         1  excitatory    CTX
# 2           3         2  excitatory    CTX
# 3           4         3  excitatory    CTX
# 4           5         4  excitatory    CTX
# 5           6         5  excitatory    CTX
# 6           7         0  excitatory    CTX
# 7           8         1  excitatory    CTX
# 8           9         0  excitatory    CTX
# 9          10         1  excitatory    CTX
# 10         11         2  excitatory    CTX
# 11         12         3  excitatory    CTX
# 12         13         4  excitatory    CTX
# 13         14         5  excitatory    CTX
# 14         15         6  excitatory    CTX
# 15         16         0  excitatory    CTX
# 16         17         1  excitatory    CTX
# 17         18         2  excitatory    CTX
# 18         19         3  excitatory    CTX
# 19         20         4  excitatory    CTX
# 20         21         5  excitatory    CTX
# ...

# %%
len(df.iloc[0]["spike_times"])
# Out:
# 2312

# %%
dh.asset.size
# Out:
# 1470449920

# %%
from pprint import pprint
pprint(dh.asset.get_metadata().__str__())
# Out:
# ("id='dandiasset:08787c6f-a1b0-489a-a21e-b0a1b4a590b1' schemaKey='Asset' "
#  "schemaVersion='0.4.4' name=None description=None contributor=None about=None "
#  'studyTarget=None license=None protocol=None ethicsApproval=None '
#  'keywords=None acknowledgement=None access=[AccessRequirements(id=None, '
#  "schemaKey='AccessRequirements', status=<AccessType.OpenAccess: "
#  "'dandi:OpenAccess'>, contactPoint=None, description=None, "
#  'embargoedUntil=None)] url=None '
#  "repository=AnyHttpUrl('https://dandiarchive.org/', ) relatedResource=None "
#  "wasGeneratedBy=[Session(id=None, schemaKey='Session', "
#  "identifier='BWRat17_121912', name='BWRat17_121912', description='Data was "
#  'recorded using silicon probe electrodes in the frontal cortices of male Long '
#  'Evans rats between 4-7 months of age. The design was to have no specific '
#  'behavior, task or stimulus, rather the animal was left alone in it’s home '
# ...

# %%
dh.asset.get_metadata().__dir__()
# Out:
# ['id',
#  'schemaKey',
#  'schemaVersion',
#  'name',
#  'description',
#  'contributor',
#  'about',
#  'studyTarget',
#  'license',
#  'protocol',
#  'ethicsApproval',
#  'keywords',
#  'acknowledgement',
#  'access',
#  'url',
#  'repository',
#  'relatedResource',
#  'wasGeneratedBy',
#  'contentSize',
#  'encodingFormat',
#  'digest',
#  'path',
#  'dateModified',
#  'blobDateModified',
#  'dataType',
#  'sameAs',
#  'approach',
#  'measurementTechnique',
#  'variableMeasured',
#  'wasDerivedFrom',
#  'wasAttributedTo',
#  'identifier',
#  'contentUrl',
#  '__config__',
#  '__fields__',
#  '__exclude_fields__',
#  '__include_fields__',
#  '__validators__',
#  '__pre_root_validators__',
#  '__post_root_validators__',
#  '__schema_cache__',
#  '__json_encoder__',
#  '__custom_root_type__',
#  '__private_attributes__',
#  '__slots__',
#  '__hash__',
#  '__class_vars__',
#  '__module__',
#  '__annotations__',
#  '__doc__',
#  '__abstractmethods__',
#  '_abc_impl',
# ...
