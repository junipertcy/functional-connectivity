# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")

from nwbwidgets import nwb2widget

import functional_connectivity as fc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dandi_set = fc.DandiHandler("000041", "sub-BWRat17/sub-BWRat17_ses-BWRat17-121912_ecephys.nwb")
# dandi_set = fc.DandiHandler("000041", "sub-BWRat17/sub-BWRat17_ses-BWRat17-121712_ecephys.nwb")
# dandi_set = fc.DandiHandler("000041", "sub-BWRat18/sub-BWRat18_ses-BWRat18-020513_ecephys.nwb")
# dandi_set = fc.DandiHandler("000041", "sub-Dino/sub-Dino_ses-Dino-062014_ecephys.nwb")

# %%
print(s3_url := dandi_set.get_s3_url())
# Out:
# A newer version (0.58.1) of dandi/dandi-cli is available. You are using 0.58.0
# This dataset is of size 1.4GB.
# https://dandiarchive.s3.amazonaws.com/blobs/ad8/b1e/ad8b1e79-102a-4cc9-98a1-1ee60d1a3396

# %%
# %%time 

nwbfile = dandi_set.read()
# Out:
# CPU times: user 1.04 ms, sys: 91 µs, total: 1.13 ms
# Wall time: 1.09 ms

# %%
nwbfile
# Out:
# root pynwb.file.NWBFile at 0x7090453328
# Fields:
#   devices: {
#     implant <class 'pynwb.device.Device'>
#   }
#   electrode_groups: {
#     shank1 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank10 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank11 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank12 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank13 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank14 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank15 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank16 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank17 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank18 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank2 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank3 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank4 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank5 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank6 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     shank7 <class 'pynwb.ecephys.ElectrodeGroup'>,
# ...

# %%
dandi_set.get_spike_counts(100)
# Out:
# <xarray.DataArray (neuron: 36, time: 309)>
# array([[7.200e+01, 5.100e+01, 4.600e+01, ..., 5.200e+01, 7.000e+00,
#         8.000e+00],
#        [1.397e+03, 1.154e+03, 1.207e+03, ..., 2.122e+03, 3.720e+02,
#         2.440e+02],
#        [2.300e+01, 1.500e+01, 1.800e+01, ..., 2.800e+01, 8.000e+00,
#         7.000e+00],
#        ...,
#        [1.070e+02, 1.500e+02, 1.320e+02, ..., 1.390e+02, 2.000e+00,
#         2.800e+01],
#        [1.300e+01, 1.200e+01, 1.200e+01, ..., 1.300e+01, 1.000e+00,
#         3.000e+00],
#        [4.780e+02, 2.560e+02, 2.100e+02, ..., 7.230e+02, 1.760e+02,
#         2.100e+02]])
# Coordinates:
#   * neuron     (neuron) <U2 '0' '1' '2' '3' '4' '5' ... '31' '32' '33' '34' '35'
#   * time       (time) object [5.0, 105.0) [105.0, 205.0) ... [22334.0, 22358.0)
#     label      (time) <U7 'Awake' 'Awake' 'Awake' ... 'Awake' 'Awake' 'Non-REM'
#     cell_type  (neuron) <U10 'excitatory' 'inhibitory' ... 'inhibitory'
# ...

# %%
nwb2widget(nwbfile)

# %%
from pprint import pprint
pprint(dandi_set.asset.get_metadata().__str__())
# Out:
# ("id='dandiasset:08787c6f-a1b0-489a-a21e-b0a1b4a590b1' schemaKey='Asset' "
#  "schemaVersion='0.4.4' name=None description=None contributor=None about=None "
#  'studyTarget=None license=None protocol=None ethicsApproval=None '
#  'keywords=None acknowledgement=None access=[AccessRequirements(id=None, '
#  "schemaKey='AccessRequirements', status=<AccessType.OpenAccess: "
#  "'dandi:OpenAccess'>, contactPoint=None, description=None, "
#  'embargoedUntil=None)] url=None '
#  "repository=AnyHttpUrl('https://dandiarchive.org/', ) relatedResource=None "
#  "wasGeneratedBy=[Session(id=None, schemaKey='Session', "
#  "identifier='BWRat17_121912', name='BWRat17_121912', description='Data was "
#  'recorded using silicon probe electrodes in the frontal cortices of male Long '
#  'Evans rats between 4-7 months of age. The design was to have no specific '
#  'behavior, task or stimulus, rather the animal was left alone in it’s home '
# ...
